# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import libs.week1 as week1
import libs.week2 as week2
import libs.week3 as week3
import matplotlib.pyplot as plt
import  numpy as np

# %%
matrix = np.array([[-1, 0, -0.8], [1, -1, -0.5]])


y_axis = []
x_axis = list(np.arange(0, 1, 0.001))+[1.0]
for x in x_axis:
    row_strategy = np.array([x, 1-x])
    y_axis.append(week1.best_response_value_row(matrix=matrix, row_strategy=row_strategy))

plt.plot(x_axis, y_axis, '.')
